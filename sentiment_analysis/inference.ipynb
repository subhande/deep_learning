# %%
import os
print(os.getcwd())
os.chdir("/content/drive/MyDrive/upwork/sentiment_ananlysis")
print(os.getcwd())
# Out:
# /content/drive/.shortcut-targets-by-id/120/sentiment_ananlysis
# /content/drive/.shortcut-targets-by-id/120/sentiment_ananlysis

# %%
# !pip install -r test_requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html, https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 1.5MB 13.8MB/s
# ...
#      |████████████████████████████████| 22.2MB 1.7MB/s
# ...
#      |████████████████████████████████| 81kB 2.2MB/s
# ...
#      |████████████████████████████████| 645kB 42.1MB/s
# ...
#      |████████████████████████████████| 159.4MB 88kB/s
# ...
#      |████████████████████████████████| 11.9MB 67.8MB/s
# ...
#      |████████████████████████████████| 2.9MB 47.7MB/s
# ...
#      |████████████████████████████████| 890kB 42.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=cc20f8f103099252cdc087cd68a2d0bb200f73bedf610a14cf67c542ce6daa2e
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
# ...

# %%
# !ls
# Out:
# config.yaml		    inference.py  README.pdf
# eda_feedback_dataset.ipynb  logs	  sentiment_analysis.ipynb
# feedback_data_pred.csv	    models	  test_requirements.txt
# feedback_data.xlsx	    __pycache__   trainer.py
# inference.ipynb		    README.md	  train_requirements.txt

# %%
# !python inference.py
# Out:
# 2021-02-10 08:38:19.523039: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Dataset Size:  (27583, 4)
# Downloading: 100% 232k/232k [00:00<00:00, 690kB/s]
# Downloading: 100% 433/433 [00:00<00:00, 396kB/s]
# Downloading: 100% 440M/440M [00:05<00:00, 83.2MB/s]
# 100% 27583/27583 [47:21<00:00,  9.71it/s]
# Predicted dataframe saved......................
